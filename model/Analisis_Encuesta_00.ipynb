# %% [markdown]
# # Analisis de los datos de la encuesta Jumping Girls (25-04-05)
#
# ## SIN CONSOLIDAR

# %%
import pandas as pd

# %%
encuesta_ESP = "Encuesta Digital Girls_SPA_ORIGINAL.xlsx"

# %%
df = pd.read_excel(encuesta_ESP)
df.head()
# Out:
#                  Label  Dibujar o pintar  Inventar historias  \
# 0  NEGOCIOS Y FINANZAS                 2                   1
# 1  NEGOCIOS Y FINANZAS                 3                   3
# 2  NEGOCIOS Y FINANZAS                 1                   1
# 3  NEGOCIOS Y FINANZAS                 1                   2
# 4  NEGOCIOS Y FINANZAS                 3                   2
#
#    Actuar, bailar y cantar  Contruir cosas con bloques  \
# 0                        1                           3
# 1                        3                           2
# 2                        1                           1
# 3                        1                           3
# 4                        1                           2
#
#    Hacer experimentos o jugar con química  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       2
# 4                                       1
#
#    Observar insectos, plantas o estrellas  Hacer manualidades  \
# 0                                       1                   3
# 1                                       1                   3
# 2                                       2                   2
# 3                                       1                   1
# 4                                       1                   1
#
#    Hacer preguntas sobre comó funcionan las cosas  Hacer deporte  ...  \
# 0                                               2              1  ...
# 1                                               2              2  ...
# 2                                               3              3  ...
# 3                                               3              3  ...
# 4                                               2              3  ...
#
#    Presentar cosas en publico  Jugar con animales  \
# 0                           1                   1
# 1                           2                   1
# 2                           1                   1
# 3                           3                   2
# 4                           2                   1
#
#    Jugar con ordenadores o videojuegos  Resolver acertijos  \
# 0                                    1                   3
# 1                                    2                   1
# 2                                    2                   2
# 3                                    2                   2
# 4                                    2                   3
#
#    Aprender sobre el cuerpo humano  Hacer cosas en equipo  Estar solo  \
# 0                                3                      3           1
# 1                                1                      3           1
# 2                                2                      3           1
# 3                                1                      3           2
# 4                                2                      3           1
#
#    Jugar a ser profesores  \
# 0                       3
# 1                       3
# 2                       3
# 3                       2
# 4                       2
#
#    Marca cuáles eran tus 2 asignaturas favoritas en el colegio o instituto:  \
# 0                               matemáticas, idiomas
# 1                              lengua, arte y dibujo
# 2                      matemáticas, educación física
# 3                              matemáticas, ciencias
# 4                            historia, arte y dibujo
#
#   Si tienes que elegir, ¿con qué personalidad de las siguientes te identificas?
# 0                                        Organizador
# 1                                             Social
# 2                                           Realista
# 3                                        Organizador
# 4                                             Social
#
# [5 rows x 21 columns]

# %%
print("Tenemos ", df['Label'].count(), "respuestas de la encuesta en Español")
# Out:
# Tenemos  356 respuestas de la encuesta en Español

# %%
# por categorias profesionales
df['Label'].value_counts()
# Out:
# NEGOCIOS Y FINANZAS                     106
# TEGNOLOGIA E INFORMATICA                 49
# SALUD Y MEDICINA                         43
# DERECHO Y CIENCIAS SOCIALES              35
# INGENIERIA Y CONSTRUCCION                32
# EDUCACIÓN Y FORMACIÓN                    25
# COMUNICACIÓN Y MEDIOS                    25
# CREATIVAS Y ARTISTICAS                   13
# TECNOLOGIA E INFORMATICA                 13
# CIENCIAS CIENTIFICAS E INVESTIGACION      8
# NATURALEZA Y MEDIO AMBIENTE               7
# Name: Label, dtype: int64

# %%
encuesta_ENG = "Encuesta Digital Girls_ENG_ORIGINAL.xlsx"

# %%
df = pd.read_excel(encuesta_ENG)
df.head()
# Out:
#                     Label  Dibujar o pintar  Inventar historias  \
# 0    BUSINESS AND FINANCE                 3                   1
# 1  LAW AND SOCIAL SCIENCE                 3                   3
# 2     HEALTH AND MEDICINE                 3                   3
# 3  LAW AND SOCIAL SCIENCE                 1                   2
# 4    BUSINESS AND FINANCE                 1                   2
#
#    Actuar, bailar y cantar  Contruir cosas con bloques  \
# 0                        1                           3
# 1                        2                           1
# 2                        1                           2
# 3                        1                           1
# 4                        1                           3
#
#    Hacer experimentos o jugar con química  \
# 0                                       1
# 1                                       1
# 2                                       2
# 3                                       1
# 4                                       2
#
#    Observar insectos, plantas o estrellas  Hacer manualidades  \
# 0                                       1                   3
# 1                                       1                   3
# 2                                       1                   2
# 3                                       2                   1
# 4                                       3                   2
#
#    Hacer preguntas sobre comó funcionan las cosas  Hacer deporte  ...  \
# 0                                               3              1  ...
# 1                                               1              2  ...
# 2                                               1              3  ...
# 3                                               3              1  ...
# 4                                               3              3  ...
#
#    Presentar cosas en publico  Jugar con animales  \
# 0                           1                   1
# 1                           2                   1
# 2                           2                   1
# 3                           1                   1
# 4                           1                   1
#
#    Jugar con ordenadores o videojuegos  Resolver acertijos  \
# 0                                    1                   3
# 1                                    1                   2
# 2                                    3                   2
# 3                                    1                   3
# 4                                    3                   3
#
#    Aprender sobre el cuerpo humano  Hacer cosas en equipo  Estar solo  \
# 0                                2                      1           2
# 1                                2                      2           1
# 2                                3                      3           1
# 3                                1                      3           1
# 4                                1                      3           3
#
#    Jugar a ser profesores  Select your 2 favourite subjetcs at school  \
# 0                       3                      maths, other languages
# 1                       3           other languages, arts and drawing
# 2                       2                   science, arts and drawing
# 3                       1                         history, literature
# 4                       1                   maths, physical education
#
#   If you need to choose, which one ot these types of personality you feel more identified with?
# 0  Investigator: I like to analyze things careful...
# 1  Social: what I like most is engaging with peop...
# 2  Investigator: I like to analyze things careful...
# 3  Investigator: I like to analyze things careful...
# 4  Entrepeneur: I enjoy starting new things with ...
#
# [5 rows x 21 columns]

# %%
# por categorias profesionales
df['Label'].value_counts()
# Out:
# BUSINESS AND FINANCE        106
# LAW AND SOCIAL SCIENCE       10
# TECHNOLOGY AND COMPUTING      6
# HEALTH AND MEDICINE           4
# COMMUNICATIONS AND MEDIA      2
# CREATIVE AND ARTISTIC         2
# EDUCATION AND TRAINING        1
# Name: Label, dtype: int64

# %% [markdown]
# ### Analisis de la distribución

# %%
import matplotlib.pyplot as plt

# %%
# Contar las clases
label_counts = df['Label'].value_counts()

# Crear gráfico de barras
ax = label_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Títulos y etiquetas
plt.title("Survey Data Distribution (Spanish + English)")
plt.xlabel("Profession (Label)")
plt.ylabel("Records")
plt.xticks(rotation=45, ha='right')

plt.ylim(0, 270)

# Añadir etiquetas de valor encima de cada barra
for i, value in enumerate(label_counts):
    ax.text(i, value + 2, str(value), ha='center', va='bottom', fontsize=9)

#plt.tight_layout()
plt.show()

# %% [markdown]
# ## Problemas
#
# #### 1. En ambas encuestas hay una profesión que es mucho mas numerosa que las demás.
#
# #### 2. Para algunas profesiones ("NATURALEZA Y MEDIO AMBIENTE" y otras) hay muy pocos ejemplos.
#
# #### 3. Aplicamos XGBoost + SMOTE para intentar balancear las clases
